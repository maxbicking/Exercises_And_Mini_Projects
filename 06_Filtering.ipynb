# %% [markdown]
# # Filtering Data Exercise
# Answer the following questions using the `bestsellers.csv` dataset

# %%
import pandas as pd
bestsellers = pd.read_csv("data/bestsellers.csv")
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## Find the books written by Pete Souza

# %% [markdown]
# ### Solution

# %%
bestsellers[bestsellers["Author"] == "Pete Souza"]
# Out:
#                             Name      Author  User Rating  Reviews  Price  \
# 244  Obama: An Intimate Portrait  Pete Souza          4.9     3192     22
#
#      Year        Genre
# 244  2017  Non Fiction

# %% [markdown]
# ### Alternatively...

# %%
pete_souza = bestsellers["Author"] == "Pete Souza"
bestsellers[pete_souza]
# Out:
#                             Name      Author  User Rating  Reviews  Price  \
# 244  Obama: An Intimate Portrait  Pete Souza          4.9     3192     22
#
#      Year        Genre
# 244  2017  Non Fiction

# %% [markdown]
# ## Find the books that are under 10 dollars

# %% [markdown]
# ### Solution

# %%
bargains = bestsellers["Price"] < 10
bestsellers[bargains]
# Out:
#                                                   Name           Author  \
# 0                        10-Day Green Smoothie Cleanse         JJ Smith
# 3                               1984 (Signet Classics)    George Orwell
# 8        A Higher Loyalty: Truth, Lies, and Leadership      James Comey
# 9                            A Man Called Ove: A Novel  Fredrik Backman
# 10                           A Man Called Ove: A Novel  Fredrik Backman
# ..                                                 ...              ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %% [markdown]
# ### Alternatively...

# %%
bestsellers[bestsellers["Price"] < 10]
# Out:
#                                                   Name           Author  \
# 0                        10-Day Green Smoothie Cleanse         JJ Smith
# 3                               1984 (Signet Classics)    George Orwell
# 8        A Higher Loyalty: Truth, Lies, and Leadership      James Comey
# 9                            A Man Called Ove: A Novel  Fredrik Backman
# 10                           A Man Called Ove: A Novel  Fredrik Backman
# ..                                                 ...              ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %% [markdown]
# ## Find the books that have a price between 50 and 60 dollars

# %% [markdown]
# ### Solution

# %%
bestsellers[bestsellers["Price"].between(50, 60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %% [markdown]
# ## Find all the books written by Kristin Hannah, Andy Weir, or Delia Owens

# %% [markdown]
# ### Solution

# %%
names = ["Kristin Hannah", "Andy Weir", "Delia Owens"]
bestsellers[bestsellers["Author"].isin(names)]
# Out:
#                          Name          Author  User Rating  Reviews  Price  \
# 433               The Martian       Andy Weir          4.7    39459      9
# 437  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 438  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 534   Where the Crawdads Sing     Delia Owens          4.8    87841     15
#
#      Year    Genre
# 433  2015  Fiction
# 437  2015  Fiction
# 438  2016  Fiction
# 534  2019  Fiction

# %% [markdown]
# ## Find the Non Fiction books that are rated 4.9

# %% [markdown]
# ### Solution

# %%
bestsellers[(bestsellers["Genre"] == "Non Fiction") & (bestsellers["User Rating"] == 4.9)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 174                       Humans of New York : Stories     Brandon Stanton
# 187  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 188  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 189  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 190  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 191  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 192  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 244                        Obama: An Intimate Portrait          Pete Souza
# 431                                 The Magnolia Story         Chip Gaines
# 521                             Unfreedom of the Press       Mark R. Levin
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %% [markdown]
# ### Alternatively, a little cleaner...

# %%
nonfiction = bestsellers["Genre"] == "Non Fiction"
high_rating = bestsellers["User Rating"] == 4.9
bestsellers[nonfiction & high_rating]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 174                       Humans of New York : Stories     Brandon Stanton
# 187  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 188  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 189  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 190  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 191  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 192  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 244                        Obama: An Intimate Portrait          Pete Souza
# 431                                 The Magnolia Story         Chip Gaines
# 521                             Unfreedom of the Press       Mark R. Levin
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %% [markdown]
# ## Find the fiction book with the lowest User Rating

# %% [markdown]
# ### Solution - lol it's JK Rowling

# %%
bestsellers[bestsellers["Genre"] == "Fiction"].sort_values("User Rating")
# Out:
#                                                   Name           Author  \
# 353                                 The Casual Vacancy     J.K. Rowling
# 132                         Go Set a Watchman: A Novel       Harper Lee
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 392  The Goldfinch: A Novel (Pulitzer Prize for Fic...      Donna Tartt
# ..                                                 ...              ...
# 41            Brown Bear, Brown Bear, What Do You See?  Bill Martin Jr.
# 40            Brown Bear, Brown Bear, What Do You See?  Bill Martin Jr.
# 476                        The Very Hungry Caterpillar       Eric Carle
# 478                        The Very Hungry Caterpillar       Eric Carle
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# 353          3.3     9372     12  2012  Fiction
# ...

# %% [markdown]
# ## Find 2012's top 5 Fiction books with the most Reviews

# %% [markdown]
# ### Solution - Wasn't sure if it was asking to sort by rating AND # reviews, so I did both

# %% [markdown]
# * Just sorting by # reviews

# %%
year_2012 = bestsellers["Year"] == 2012
fiction = bestsellers["Genre"] == "Fiction"
bestsellers[year_2012 & fiction].sort_values("Reviews", ascending = False).head()
# Out:
#                                                   Name           Author  \
# 135                                          Gone Girl    Gillian Flynn
# 365                             The Fault in Our Stars       John Green
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 409                          The Hunger Games (Book 1)  Suzanne Collins
# 238                      Mockingjay (The Hunger Games)  Suzanne Collins
#
#      User Rating  Reviews  Price  Year    Genre
# 135          4.0    57271     10  2012  Fiction
# 365          4.7    50482     13  2012  Fiction
# 106          3.8    47265     14  2012  Fiction
# 409          4.7    32122      8  2012  Fiction
# 238          4.5    26741      8  2012  Fiction

# %% [markdown]
# * Sorting by rating and then review - I dont think this was what he was asking

# %%
year_2012 = bestsellers["Year"] == 2012
fiction = bestsellers["Genre"] == "Fiction"
bestsellers[year_2012 & fiction].sort_values(["User Rating", "Reviews"], ascending = False).head()
# Out:
#                                                   Name                Author  \
# 245                          Oh, the Places You'll Go!             Dr. Seuss
# 146  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
# 411             The Hunger Games Trilogy Boxed Set (1)       Suzanne Collins
# 432     The Mark of Athena (Heroes of Olympus, Book 3)          Rick Riordan
# 458  The Serpent's Shadow (The Kane Chronicles, Boo...          Rick Riordan
#
#      User Rating  Reviews  Price  Year    Genre
# 245          4.9    21834      8  2012  Fiction
# 146          4.9     7038      7  2012  Fiction
# 411          4.8    16949     30  2012  Fiction
# 432          4.8     6247     10  2012  Fiction
# 458          4.8     2091     12  2012  Fiction

# %% [markdown]
# ## Create a bar plot showing the 5 authors who have the most books with a rating under 4.5

# %% [markdown]
# ### Solution

# %%
rating = bestsellers["User Rating"] < 4.5
bestsellers[rating]
# Out:
#                                                   Name               Author  \
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 17      Adult Coloring Book: Stress Relieving Patterns   Blue Star Coloring
# 22                                           Allegiant        Veronica Roth
# 24                            And the Mountains Echoed      Khaled Hosseini
# 27                 Autobiography of Mark Twain, Vol. 1           Mark Twain
# ..                                                 ...                  ...
# 530               What to Expect When You're Expecting        Heidi Murkoff
# 531  Wheat Belly: Lose the Wheat, Lose the Weight, ...        William Davis
# 532  Wheat Belly: Lose the Wheat, Lose the Weight, ...        William Davis
# 537  Wild: From Lost to Found on the Pacific Crest ...       Cheryl Strayed
# 539  Women Food and God: An Unexpected Path to Almo...          Geneen Roth
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
bestsellers[rating].value_counts("Author")
# Out:
# Author
# Gallup                    9
# The College Board         6
# E L James                 4
# F. Scott Fitzgerald       3
# John Grisham              3
# Dan Brown                 3
# Gillian Flynn             3
# J. D. Vance               2
# Stieg Larsson             2
# Paula Hawkins             2
# Malcolm Gladwell          2
# Laurel Randolph           2
# Jennifer Smith            2
# J.K. Rowling              2
# Amy Ramos                 2
# Greg Mortenson            2
# William Davis             2
# Charlaine Harris          2
# Eben Alexander            2
# Doug Lemov                2
# Daniel Lipkowitz          2
# Donna Tartt               2
# Paula McLain              1
# Mark Twain                1
# Michael Pollan            1
# Michael Wolff             1
# Mike Moreno               1
# Muriel Barbery            1
# Paper Peony Press         1
# Bob Woodward              1
# Eric Larson               1
# Mark Hyman M.D.           1
# Rob Bell                  1
# ...

# %%
bestsellers[rating].value_counts("Author").head().sort_values().plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Author'>
